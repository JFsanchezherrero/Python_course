# %% [markdown]
# # <i class="fa fa-laptop"></i> Bioinformatic Programming using Python
#
# <div style="background-color: #86CBBB; 1px; height:3px " ></div>
#
# Here, we will demonstrate some of the basics of programming Python. If you want to lean more, there are many more resources and other training sessions out there, including the official [Python Tutorial](https://docs.python.org/3/tutorial/).
#
# In this Jupyter _notebook_ you can answer and practice the exercises from this practical session.
#
# There are several icons that denome:
#
# * **<i class="fa fa-search"></i> Example**: Some code examples available for the topic of interest.
# * **<i class="fa fa-pencil"></i> Activitities**: These are actitivies to practice the lessons topics.
# * **<i class="fa fa-key"></i> Hint:** A small hint on how to solve the exercise.
# * **<i class="fa fa-cogs"></i> Code:** You write here the code. More than one line can be provided in the same code block. The symbol "..." expects to be replaced by some code.
# * **<i class="fa fa-file-code-o"></i> Script:** Intrusctions are provided to create an external script code using the terminal or other resources.
# * **<i class="fa fa-comment"></i> Comments:** Write your comments or notes in here if desired. This cell is formatted using Markdown. To activate it, click and write and then press Run or Execute.
# * **<i class="fa fa-rocket"></i> Challenge**: Activitities to test your coding skills.
#
# ## Getting Started
#
# Jupyter notebooks have two types of cells.  "Markdown" cells, like this one which can contain formatted text, and "Code" cells, which contain the code you will run.
#
# After you execute the cell, the result will automatically display underneath the cell.
#
#
# ## Jupyter menu
#
# To use the jupyter menu there are several buttons and options. See below a small description, see additional details [here](https://jupyter.brynmawr.edu/services/public/dblank/Jupyter%20Notebook%20Users%20Manual.ipynb) or [here](https://jupyter-notebook.readthedocs.io/en/latest/examples/Notebook/Notebook%20Basics.html#Notebook-Basics)
#
# * <i class="fa fa-save"></i> This is your save button. You can click this button to save your notebook at any time, though keep in mind that Jupyter Notebooks automatically save your progress very frequently.
#
# * <i class="fa fa-plus"></i> This is the new cell button. You can click this button any time you want a new cell in your Jupyter Notebook.
#
# * <i class="fa fa-scissors"></i> This is the cut cell button. If you click this button, the cell you currently have selected will be deleted from your Notebook.
#
# * <i class="fa fa-copy"></i> This is the copy cell button. If you click this button, the currently selected cell will be duplicated and stored in your clipboard.
#
# * <i class="fa fa-paste"></i> This is the past button. It allows you to paste the duplicated cell from your clipboard into your notebook.
#
# * <i class="fa fa-arrow-up"></i><i class="fa fa-arrow-down"></i> These buttons allow you to move the location of a selected cell within a Notebook. Simply select the cell you wish to move and click either the up or down button until the cell is in the location you want it to be.
#
# * <i class="fa fa-step-forward"></i> This button will "run" your cell, meaning that it will interpret your input and render the output in a way that depends on what type of cell you're using.
#
# * <i class="fa fa-step-forward"></i> This is the restart kernel button. See your kernel documentation for more information.
#
# * <i class="fa fa-stop"></i> This is the stop button. Clicking this button will stop your cell from continuing to run. This tool can be useful if you are trying to execute more complicated code, which can sometimes take a while, and you want to edit the cell before waiting for it to finish rendering.
#
# * <i class="fa fa-repeat"></i> esborra les variables que hi havia guardades fins al moment
#
#
# There are also several shorcuts available, check the list in:
#
# ![image-2.png](attachment:image-2.png)
#
# Some examples:
#
# **Edit mode**: Enter
# **Run cell**: Shift-Enter, Ctrl-Enter,
# **Basic browsing**: , up arrow/k, down arrow/j, esc <br>
# **Save the notebook**: S
# **Change cell format type**: M, Y
# **Create new cells**: A ( insert cell above), B (insert cell below)
# **Edit cells**: X (Cut), C (Copy), V (Paste) D (Delete), Z (Undo cell selection)
# **Show keyboard shorcuts**: H
#
# <br>
#
#  <div style="background-color: #86CBBB; 1px; height:3px " ></div>

# %% [markdown]
# # Some basic introduction to python: Pandas dataframes
# Let's review a few basic features of advanced python programming data types.

# %% [markdown]
# ## Pandas dataframes

# %% [markdown]
# **_Pandas Dataframes_**
#
# [pandas](https://pandas.pydata.org/docs/index.html#module-pandas) is a library providing high-performance, easy-to-use data structures and data analysis tools.
#
# Dataframes contain:
# - Data organized in 2 dimensions, rows and columns
# - Labels that correspond to the rows and columns
#
# Pandas dataframe:
# - has functions for analyzing, exploring, and manipulating data.
# - can clean messy data sets (missing, NULL, wrong values), and make them readable and relevant.
# - allows us to analyze big data and make conclusions based on statistical theories.
#
#
#
# Additional details [here](https://realpython.com/pandas-dataframe/) and tutorials [there](https://www.w3schools.com/python/pandas/default.asp)
#
# ### <i class="fa fa-search"></i> Example

# %% [markdown]
# #### Create dataframes

# %%
# import package
import pandas

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pandas.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
type(mydataset)
# Out:
# dict

# %%
type(myvar)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Check version of package:

# %%
## check version of package
import pandas
print(pandas.__version__)
# Out:
# 1.4.4

# %% [markdown]
# #### Use alias to import pandas

# %% [markdown]
# You can also use an alias.
#
# In Python alias are an alternate name for referring to the same thing.
#
# Now the Pandas package can be referred to as `pd` instead of `pandas`.

# %%
# import package and use abbreviation
import pandas as pd

data = {
    'name': ['Xavier', 'Ann', 'Jana', 'Yi', 'Robin', 'Amal', 'Nori'],
    'city': ['Mexico City', 'Toronto', 'Prague', 'Shanghai','Manchester', 'Cairo', 'Osaka'],
    'age': [41, 28, 33, 34, 38, 31, 37],
    'py-score': [88.0, 79.0, 81.0, 80.0, 68.0, 61.0, 84.0]
}

row_labels = [101, 102, 103, 104, 105, 106, 107]

df = pd.DataFrame(data=data, index=row_labels)

df
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      79.0
# 103    Jana       Prague   33      81.0
# 104      Yi     Shanghai   34      80.0
# 105   Robin   Manchester   38      68.0
# 106    Amal        Cairo   31      61.0
# 107    Nori        Osaka   37      84.0

# %% [markdown]
# #### Head & tail

# %% [markdown]
# `pandas` DataFrames can sometimes be very large, making it impractical to look at all the rows at once. You can use `.head()` to show the first few items and `.tail()` to show the last few items.
#
# You can use the number of rows to show, using the parameter `n`.

# %%
df.head(n=3)
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      79.0
# 103    Jana       Prague   33      81.0

# %%
df.tail(n=3)
# Out:
#       name        city  age  py-score
# 105  Robin  Manchester   38      68.0
# 106   Amal       Cairo   31      61.0
# 107   Nori       Osaka   37      84.0

# %% [markdown]
# #### Find index & columns names, and other information

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (7, 4)

# %%
df.size
# Out:
# 28

# %%
## find index IDs
df.index
# Out:
# Int64Index([101, 102, 103, 104, 105, 106, 107], dtype='int64')

# %%
# find columns
df.columns
# Out:
# Index(['name', 'city', 'age', 'py-score'], dtype='object')

# %%
len(df.columns)
# Out:
# 4

# %%
df.columns[1]
# Out:
# 'city'

# %%
df.dtypes
# Out:
# name         object
# city         object
# age           int64
# py-score    float64
# dtype: object

# %% [markdown]
# As you can see, `.dtypes` returns a Series object with the column names as labels and the corresponding data types as values.

# %% [markdown]
# #### Access data in dataframes

# %% [markdown]
# You can access a column in a `pandas` DataFrame the same way you would get a value from a dictionary:

# %%
## access columns
df['city']
# Out:
# 101    Mexico City
# 102        Toronto
# 103         Prague
# 104       Shanghai
# 105     Manchester
# 106          Cairo
# 107          Osaka
# Name: city, dtype: object

# %% [markdown]
# If the name of the column is a string that is a valid Python identifier, then you can use dot notation to access it. That is, you can access the column the same way you would get the attribute of a class instance:

# %%
## access columns too
df.city
# Out:
# 101    Mexico City
# 102        Toronto
# 103         Prague
# 104       Shanghai
# 105     Manchester
# 106          Cairo
# 107          Osaka
# Name: city, dtype: object

# %% [markdown]
# Also, pandas has four accessors in total:
#
# - `.loc[]` accepts the labels of rows and columns and returns Series or DataFrames. You can use it to get entire rows or columns, as well as their parts.
#
# - `.iloc[]` accepts the zero-based indices of rows and columns and returns Series or DataFrames. You can use it to get entire rows or columns, or their parts.
#
# - `.at[]` accepts the labels of rows and columns and returns a single data value.
#
# - `.iat[]` accepts the zero-based indices of rows and columns and returns a single data value.

# %%
df
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      79.0
# 103    Jana       Prague   33      81.0
# 104      Yi     Shanghai   34      80.0
# 105   Robin   Manchester   38      68.0
# 106    Amal        Cairo   31      61.0
# 107    Nori        Osaka   37      84.0

# %%
## Access a row
df.loc[103]
# Out:
# name          Jana
# city        Prague
# age             33
# py-score      81.0
# Name: 103, dtype: object

# %%
## Access a row using zero-based indices
df.iloc[2]
# Out:
# name          Jana
# city        Prague
# age             33
# py-score      81.0
# Name: 103, dtype: object

# %% [markdown]
# #### Slicing dataframes

# %% [markdown]
# `.loc[]` and `.iloc[]` are particularly powerful. They support slicing and NumPy-style indexing. You can use them to access a column:

# %%
df.loc[:,:]
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      79.0
# 103    Jana       Prague   33      81.0
# 104      Yi     Shanghai   34      80.0
# 105   Robin   Manchester   38      68.0
# 106    Amal        Cairo   31      61.0
# 107    Nori        Osaka   37      84.0

# %%
df.loc[ [103, 105], ['city','age']]
# Out:
#            city  age
# 103      Prague   33
# 105  Manchester   38

# %%
## slicing dataframe: from 0-3rd row, all columns included
df.iloc[:3]
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      79.0
# 103    Jana       Prague   33      81.0

# %%
## slicing dataframe: from 0-3rd row, only 0-2nd columns included
df.iloc[:3,:2]
# Out:
#        name         city
# 101  Xavier  Mexico City
# 102     Ann      Toronto
# 103    Jana       Prague

# %%
## Reversing dataframe
df.iloc[:,::-1]
# Out:
#      py-score  age         city    name
# 101      88.0   41  Mexico City  Xavier
# 102      79.0   28      Toronto     Ann
# 103      81.0   33       Prague    Jana
# 104      80.0   34     Shanghai      Yi
# 105      68.0   38   Manchester   Robin
# 106      61.0   31        Cairo    Amal
# 107      84.0   37        Osaka    Nori

# %% [markdown]
# #### Access cell values

# %% [markdown]
# It’s possible to use `.loc[]` and `.iloc[]` to get particular data values. However, when you need only a single value, pandas recommends using the specialized accessors `.at[]` and `.iat[]`:

# %%
## Access a cell value
df.at[103, 'name']
# Out:
# 'Jana'

# %%
## Access a cell value using zero-based indices
df.iat[1, 1]
# Out:
# 'Toronto'

# %% [markdown]
# #### Modify dataframes

# %%
df.loc[:, 'py-score']
# Out:
# 101    88.0
# 102    79.0
# 103    81.0
# 104    80.0
# 105    68.0
# 106    61.0
# 107    84.0
# Name: py-score, dtype: float64

# %%
df.loc[:104, 'py-score'] = [40, 50, 60, 70]

# %%
df.loc[:, 'py-score']
# Out:
# 101    40.0
# 102    50.0
# 103    60.0
# 104    70.0
# 105    68.0
# 106    61.0
# 107    84.0
# Name: py-score, dtype: float64

# %%
df.loc[104:, 'py-score'] = 0

# %%
df.loc[:, 'py-score']
# Out:
# 101    40.0
# 102    50.0
# 103    60.0
# 104     0.0
# 105     0.0
# 106     0.0
# 107     0.0
# Name: py-score, dtype: float64

# %% [markdown]
# #### Insert or delete data in dataframes

# %%
john = pd.Series(data=['John', 'Boston', 34, 79], 
                 index=df.columns, name=17)

# %%
john
# Out:
# name          John
# city        Boston
# age             34
# py-score        79
# Name: 17, dtype: object

# %%
## this might produce errors: depends on the pandas versions installed
df = df.append(john)
# Out:
# C:\Users\josed\AppData\Local\Temp\ipykernel_29652\2673772102.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(john)

# %%
df
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41      40.0
# 102     Ann      Toronto   28      50.0
# 103    Jana       Prague   33      60.0
# 104      Yi     Shanghai   34       0.0
# 105   Robin   Manchester   38       0.0
# 106    Amal        Cairo   31       0.0
# 107    Nori        Osaka   37       0.0
# 17     John       Boston   34      79.0

# %%
## remove the inserted row using drop
df = df.drop(labels=[17])

# %%
## add a new column with given values as numpy.array
import numpy as np
df['js-score'] = np.array([71.0, 95.0, 88.0, 79.0, 91.0, 91.0, 80.0])

# %%
df
# Out:
#        name         city  age  py-score  js-score
# 101  Xavier  Mexico City   41      40.0      71.0
# 102     Ann      Toronto   28      50.0      95.0
# 103    Jana       Prague   33      60.0      88.0
# 104      Yi     Shanghai   34       0.0      79.0
# 105   Robin   Manchester   38       0.0      91.0
# 106    Amal        Cairo   31       0.0      91.0
# 107    Nori        Osaka   37       0.0      80.0

# %%
## add a column in the last position with all values equals to 0.0
df['total-score'] = 0.0

# %%
df
# Out:
#        name         city  age  py-score  js-score  total-score
# 101  Xavier  Mexico City   41      40.0      71.0          0.0
# 102     Ann      Toronto   28      50.0      95.0          0.0
# 103    Jana       Prague   33      60.0      88.0          0.0
# 104      Yi     Shanghai   34       0.0      79.0          0.0
# 105   Robin   Manchester   38       0.0      91.0          0.0
# 106    Amal        Cairo   31       0.0      91.0          0.0
# 107    Nori        Osaka   37       0.0      80.0          0.0

# %%
## add a new column in a different position
df.insert(loc=4, column='django-score',
          value=np.array([86.0, 81.0, 78.0, 88.0, 74.0, 70.0, 81.0]))

# %%
df
# Out:
#        name         city  age  py-score  django-score  js-score  total-score
# 101  Xavier  Mexico City   41      40.0          86.0      71.0          0.0
# 102     Ann      Toronto   28      50.0          81.0      95.0          0.0
# 103    Jana       Prague   33      60.0          78.0      88.0          0.0
# 104      Yi     Shanghai   34       0.0          88.0      79.0          0.0
# 105   Robin   Manchester   38       0.0          74.0      91.0          0.0
# 106    Amal        Cairo   31       0.0          70.0      91.0          0.0
# 107    Nori        Osaka   37       0.0          81.0      80.0          0.0

# %% [markdown]
# #### Remove elements

# %% [markdown]
# We can remove columns in a dataframe using `del` or `.pop` and the column name

# %%
del df['total-score']
## df.pop('total-score')

# %%
df
# Out:
#        name         city  age  py-score  django-score  js-score
# 101  Xavier  Mexico City   41      40.0          86.0      71.0
# 102     Ann      Toronto   28      50.0          81.0      95.0
# 103    Jana       Prague   33      60.0          78.0      88.0
# 104      Yi     Shanghai   34       0.0          88.0      79.0
# 105   Robin   Manchester   38       0.0          74.0      91.0
# 106    Amal        Cairo   31       0.0          70.0      91.0
# 107    Nori        Osaka   37       0.0          81.0      80.0

# %% [markdown]
# You can also remove one or more columns with `.drop()` as you did previously with the rows. Again, you need to specify the labels of the desired columns with labels. In addition, when you want to remove columns, you need to provide the argument `axis=1`:

# %%
df = df.drop(labels='age', axis=1)

# %%
df
# Out:
#        name         city  py-score  django-score  js-score
# 101  Xavier  Mexico City      40.0          86.0      71.0
# 102     Ann      Toronto      50.0          81.0      95.0
# 103    Jana       Prague      60.0          78.0      88.0
# 104      Yi     Shanghai       0.0          88.0      79.0
# 105   Robin   Manchester       0.0          74.0      91.0
# 106    Amal        Cairo       0.0          70.0      91.0
# 107    Nori        Osaka       0.0          81.0      80.0

# %% [markdown]
# #### Operations on dataframes

# %%
df['py-score'] + df['js-score'] + df['django-score']
# Out:
# 101    197.0
# 102    226.0
# 103    226.0
# 104    167.0
# 105    165.0
# 106    161.0
# 107    161.0
# dtype: float64

# %%
df['total'] = df['py-score'] + df['js-score'] + df['django-score']

# %%
df
# Out:
#        name         city  py-score  django-score  js-score  total
# 101  Xavier  Mexico City      40.0          86.0      71.0  197.0
# 102     Ann      Toronto      50.0          81.0      95.0  226.0
# 103    Jana       Prague      60.0          78.0      88.0  226.0
# 104      Yi     Shanghai       0.0          88.0      79.0  167.0
# 105   Robin   Manchester       0.0          74.0      91.0  165.0
# 106    Amal        Cairo       0.0          70.0      91.0  161.0
# 107    Nori        Osaka       0.0          81.0      80.0  161.0

# %% [markdown]
# ##### Applying NumPy and SciPy Functions
#
# Most `NumPy` and `SciPy` routines can be applied to `pandas` Series or DataFrame objects as arguments instead of as `NumPy` arrays. To illustrate this, we can use `numpy.average()` function.

# %%
df.iloc[:, 2:5]
# Out:
#      py-score  django-score  js-score
# 101      40.0          86.0      71.0
# 102      50.0          81.0      95.0
# 103      60.0          78.0      88.0
# 104       0.0          88.0      79.0
# 105       0.0          74.0      91.0
# 106       0.0          70.0      91.0
# 107       0.0          81.0      80.0

# %%
np.average(df.iloc[:, 2:5], axis=1)
# Out:
# array([65.66666667, 75.33333333, 75.33333333, 55.66666667, 55.        ,
#        53.66666667, 53.66666667])

# %%
df['avg'] = np.average(df.iloc[:, 2:5], axis=1)

# %%
df
# Out:
#        name         city  py-score  django-score  js-score  total        avg
# 101  Xavier  Mexico City      40.0          86.0      71.0  197.0  65.666667
# 102     Ann      Toronto      50.0          81.0      95.0  226.0  75.333333
# 103    Jana       Prague      60.0          78.0      88.0  226.0  75.333333
# 104      Yi     Shanghai       0.0          88.0      79.0  167.0  55.666667
# 105   Robin   Manchester       0.0          74.0      91.0  165.0  55.000000
# 106    Amal        Cairo       0.0          70.0      91.0  161.0  53.666667
# 107    Nori        Osaka       0.0          81.0      80.0  161.0  53.666667

# %% [markdown]
# #### Sort dataframes

# %% [markdown]
# We can sort DataFrames by the values in the column provided. Several parameters required:
# - The parameter by sets the label of the row or column to sort by.
# - ascending specifies whether you want to sort in ascending (True) or descending (False) order, the latter being the default setting.
# - You can pass axis to choose if you want to sort rows (axis=0) or columns (axis=1).
#
# If you want to sort by multiple columns, then just pass lists as arguments for by and ascending
#
# See additional details in this link [here](https://realpython.com/pandas-sort-python/)

# %%
df.sort_values(by='avg', ascending=True)
# Out:
#        name         city  py-score  django-score  js-score  total        avg
# 106    Amal        Cairo       0.0          70.0      91.0  161.0  53.666667
# 107    Nori        Osaka       0.0          81.0      80.0  161.0  53.666667
# 105   Robin   Manchester       0.0          74.0      91.0  165.0  55.000000
# 104      Yi     Shanghai       0.0          88.0      79.0  167.0  55.666667
# 101  Xavier  Mexico City      40.0          86.0      71.0  197.0  65.666667
# 102     Ann      Toronto      50.0          81.0      95.0  226.0  75.333333
# 103    Jana       Prague      60.0          78.0      88.0  226.0  75.333333

# %%
df.sort_values(by=['city','avg'])
# Out:
#        name         city  py-score  django-score  js-score  total        avg
# 106    Amal        Cairo       0.0          70.0      91.0  161.0  53.666667
# 105   Robin   Manchester       0.0          74.0      91.0  165.0  55.000000
# 101  Xavier  Mexico City      40.0          86.0      71.0  197.0  65.666667
# 107    Nori        Osaka       0.0          81.0      80.0  161.0  53.666667
# 103    Jana       Prague      60.0          78.0      88.0  226.0  75.333333
# 104      Yi     Shanghai       0.0          88.0      79.0  167.0  55.666667
# 102     Ann      Toronto      50.0          81.0      95.0  226.0  75.333333

# %% [markdown]
# The optional parameter `inplace` can also be used with `.sort_values()`. It’s set to False by default, ensuring `.sort_values()` returns a new pandas DataFrame. When you set inplace=True, the existing DataFrame will be modified and `.sort_values()` will return `None`.

# %% [markdown]
# #### Filter dataframes

# %% [markdown]
# Data filtering is another powerful feature of `pandas`. It works similarly to indexing with Boolean arrays in NumPy.
#
# If you apply some logical operation on a Series object, then you’ll get another Series with the Boolean values `True` and `False`.

# %%
df['django-score'] >= 80
# Out:
# 101     True
# 102     True
# 103    False
# 104     True
# 105    False
# 106    False
# 107     True
# Name: django-score, dtype: bool

# %%
df[df['django-score'] >= 80]
# Out:
#        name         city  py-score  django-score  js-score  total        avg
# 101  Xavier  Mexico City      40.0          86.0      71.0  197.0  65.666667
# 102     Ann      Toronto      50.0          81.0      95.0  226.0  75.333333
# 104      Yi     Shanghai       0.0          88.0      79.0  167.0  55.666667
# 107    Nori        Osaka       0.0          81.0      80.0  161.0  53.666667

# %% [markdown]
# You can create very powerful and sophisticated expressions by combining logical operations with the following operators:
#
# - NOT (~)
# - AND (&)
# - OR (|)
# - XOR (^)

# %%
## Both conditions must be true
df[ (df['py-score'] >= 40) & (df['js-score'] >= 80)]
# Out:
#      name     city  py-score  django-score  js-score  total        avg
# 102   Ann  Toronto      50.0          81.0      95.0  226.0  75.333333
# 103  Jana   Prague      60.0          78.0      88.0  226.0  75.333333

# %%
## One of both or both: py-score >= 40 OR js-score >= 80
df[ (df['py-score'] >= 40) | (df['js-score'] >= 80)]
# Out:
#        name         city  py-score  django-score  js-score  total        avg
# 101  Xavier  Mexico City      40.0          86.0      71.0  197.0  65.666667
# 102     Ann      Toronto      50.0          81.0      95.0  226.0  75.333333
# 103    Jana       Prague      60.0          78.0      88.0  226.0  75.333333
# 105   Robin   Manchester       0.0          74.0      91.0  165.0  55.000000
# 106    Amal        Cairo       0.0          70.0      91.0  161.0  53.666667
# 107    Nori        Osaka       0.0          81.0      80.0  161.0  53.666667

# %%
## One of both, but not both!
df[ (df['py-score'] >= 40) ^ (df['js-score'] >= 80)]
# Out:
#        name         city  py-score  django-score  js-score  total        avg
# 101  Xavier  Mexico City      40.0          86.0      71.0  197.0  65.666667
# 105   Robin   Manchester       0.0          74.0      91.0  165.0  55.000000
# 106    Amal        Cairo       0.0          70.0      91.0  161.0  53.666667
# 107    Nori        Osaka       0.0          81.0      80.0  161.0  53.666667

# %% [markdown]
# #### Some data statistics

# %%
df
# Out:
#        name         city  py-score  django-score  js-score  total        avg
# 101  Xavier  Mexico City      40.0          86.0      71.0  197.0  65.666667
# 102     Ann      Toronto      50.0          81.0      95.0  226.0  75.333333
# 103    Jana       Prague      60.0          78.0      88.0  226.0  75.333333
# 104      Yi     Shanghai       0.0          88.0      79.0  167.0  55.666667
# 105   Robin   Manchester       0.0          74.0      91.0  165.0  55.000000
# 106    Amal        Cairo       0.0          70.0      91.0  161.0  53.666667
# 107    Nori        Osaka       0.0          81.0      80.0  161.0  53.666667

# %%
df.describe()
# Out:
#         py-score  django-score   js-score       total        avg
# count   7.000000      7.000000   7.000000    7.000000   7.000000
# mean   21.428571     79.714286  85.000000  186.142857  62.047619
# std    27.342623      6.343350   8.544004   29.924508   9.974836
# min     0.000000     70.000000  71.000000  161.000000  53.666667
# 25%     0.000000     76.000000  79.500000  163.000000  54.333333
# 50%     0.000000     81.000000  88.000000  167.000000  55.666667
# 75%    45.000000     83.500000  91.000000  211.500000  70.500000
# max    60.000000     88.000000  95.000000  226.000000  75.333333

# %%
df.mean()
# Out:
# C:\Users\josed\AppData\Local\Temp\ipykernel_29652\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# py-score         21.428571
# django-score     79.714286
# js-score         85.000000
# total           186.142857
# avg              62.047619
# dtype: float64

# %%
df['py-score'].mean()
# Out:
# 21.428571428571427

# %%
df['py-score'].std()
# Out:
# 27.342623276105893

# %%
## find correlations
df.corr()
# Out:
#               py-score  django-score  js-score     total       avg
# py-score      1.000000      0.204540  0.085611  0.981522  0.981522
# django-score  0.204540      1.000000 -0.704213  0.197805  0.197805
# js-score      0.085611     -0.704213  1.000000  0.214465  0.214465
# total         0.981522      0.197805  0.214465  1.000000  1.000000
# avg           0.981522      0.197805  0.214465  1.000000  1.000000

# %% [markdown]
# #### Iterate over pandas dataframes

# %% [markdown]
# Pandas DataFrame’s row and column labels can be retrieved as sequences with `.index` and `.columns`. You can use this feature to iterate over labels and get or set data values.

# %% [markdown]
# However, pandas provides several more convenient methods for iteration.
#
# Iterate columns:
# - [`.items()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.items.html) to iterate over columns
# - [`.iteritems()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iteritems.html) to iterate over columns
#
# Iterate rows:
# - [`.iterrows()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iterrows.html) to iterate over rows
# - [`.itertuples()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.itertuples.html) to iterate over rows and get named tuples

# %%
## iterate using pd.iteritems()
for col_label, col in df.iteritems():
    print("Col_label: ", col_label)
    print("col: ")
    print(col, end='\n\n')
# Out:
# Col_label:  name
# col:
# 101    Xavier
# 102       Ann
# 103      Jana
# 104        Yi
# 105     Robin
# 106      Amal
# 107      Nori
# Name: name, dtype: object
#
# Col_label:  city
# col:
# 101    Mexico City
# 102        Toronto
# 103         Prague
# 104       Shanghai
# 105     Manchester
# 106          Cairo
# 107          Osaka
# Name: city, dtype: object
#
# Col_label:  py-score
# col:
# 101    40.0
# 102    50.0
# 103    60.0
# 104     0.0
# 105     0.0
# 106     0.0
# 107     0.0
# Name: py-score, dtype: float64
#
# Col_label:  django-score
# col:
# 101    86.0
# 102    81.0
# 103    78.0
# 104    88.0
# 105    74.0
# 106    70.0
# 107    81.0
# Name: django-score, dtype: float64
#
# Col_label:  js-score
# col:
# 101    71.0
# 102    95.0
# 103    88.0
# 104    79.0
# 105    91.0
# 106    91.0
# 107    80.0
# Name: js-score, dtype: float64
#
# Col_label:  total
# col:
# 101    197.0
# 102    226.0
# 103    226.0
# 104    167.0
# 105    165.0
# 106    161.0
# 107    161.0
# Name: total, dtype: float64
#
# Col_label:  avg
# col:
# 101    65.666667
# 102    75.333333
# 103    75.333333
# 104    55.666667
# 105    55.000000
# 106    53.666667
# 107    53.666667
# Name: avg, dtype: float64

# %%
## iterate using pd.iterrows()
for row_label, row in df.iterrows():
    print("row_label: ", row_label)
    print("row: ")
    print(row, end='\n\n')
# Out:
# row_label:  101
# row:
# name                 Xavier
# city            Mexico City
# py-score               40.0
# django-score           86.0
# js-score               71.0
# total                 197.0
# avg               65.666667
# Name: 101, dtype: object
#
# row_label:  102
# row:
# name                  Ann
# city              Toronto
# py-score             50.0
# django-score         81.0
# js-score             95.0
# total               226.0
# avg             75.333333
# Name: 102, dtype: object
#
# row_label:  103
# row:
# name                 Jana
# city               Prague
# py-score             60.0
# django-score         78.0
# js-score             88.0
# total               226.0
# avg             75.333333
# Name: 103, dtype: object
#
# row_label:  104
# row:
# name                   Yi
# city             Shanghai
# py-score              0.0
# django-score         88.0
# js-score             79.0
# total               167.0
# avg             55.666667
# Name: 104, dtype: object
#
# row_label:  105
# row:
# name                 Robin
# city            Manchester
# py-score               0.0
# django-score          74.0
# js-score              91.0
# total                165.0
# avg                   55.0
# Name: 105, dtype: object
#
# row_label:  106
# row:
# name                 Amal
# city                Cairo
# py-score              0.0
# django-score         70.0
# js-score             91.0
# total               161.0
# avg             53.666667
# Name: 106, dtype: object
#
# row_label:  107
# row:
# name                 Nori
# city                Osaka
# py-score              0.0
# django-score         81.0
# js-score             80.0
# total               161.0
# avg             53.666667
# Name: 107, dtype: object

# %%
for row in df.itertuples():
    print(row)
    print(row.name)
    print("#")
# Out:
# Pandas(Index=101, name='Xavier', city='Mexico City', _3=40.0, _4=86.0, _5=71.0, total=197.0, avg=65.66666666666667)
# Xavier
# #
# Pandas(Index=102, name='Ann', city='Toronto', _3=50.0, _4=81.0, _5=95.0, total=226.0, avg=75.33333333333333)
# Ann
# #
# Pandas(Index=103, name='Jana', city='Prague', _3=60.0, _4=78.0, _5=88.0, total=226.0, avg=75.33333333333333)
# Jana
# #
# Pandas(Index=104, name='Yi', city='Shanghai', _3=0.0, _4=88.0, _5=79.0, total=167.0, avg=55.666666666666664)
# Yi
# #
# Pandas(Index=105, name='Robin', city='Manchester', _3=0.0, _4=74.0, _5=91.0, total=165.0, avg=55.0)
# Robin
# #
# Pandas(Index=106, name='Amal', city='Cairo', _3=0.0, _4=70.0, _5=91.0, total=161.0, avg=53.666666666666664)
# Amal
# #
# Pandas(Index=107, name='Nori', city='Osaka', _3=0.0, _4=81.0, _5=80.0, total=161.0, avg=53.666666666666664)
# Nori
# #

# %% [markdown]
# #### Plotting data using pandas and matplotlib

# %%
df
# Out:
#        name         city  py-score  django-score  js-score  total        avg
# 101  Xavier  Mexico City      40.0          86.0      71.0  197.0  65.666667
# 102     Ann      Toronto      50.0          81.0      95.0  226.0  75.333333
# 103    Jana       Prague      60.0          78.0      88.0  226.0  75.333333
# 104      Yi     Shanghai       0.0          88.0      79.0  167.0  55.666667
# 105   Robin   Manchester       0.0          74.0      91.0  165.0  55.000000
# 106    Amal        Cairo       0.0          70.0      91.0  161.0  53.666667
# 107    Nori        Osaka       0.0          81.0      80.0  161.0  53.666667

# %%
import matplotlib.pyplot as plt
df.plot(kind = 'scatter', x = 'name', y = 'django-score')
plt.show()

# %%
import matplotlib.pyplot as plt
df.boxplot('django-score', by='py-score')
plt.show()

# %% [markdown]
# #### Read and write information from pandas to file

# %% [markdown]
# Imagine we have information store as CSV in data.csv file

# %%
# df_example = pd.read_csv('data.csv') ## other parameters can be used

# %% [markdown]
# We can dump information to csv, excel or json format files

# %%
# df_example.to_csv()
# df_example.to_excel()
# df_example.to_json()

# %% [markdown]
# <div style="background-color: #86CBBB; font-size: 16px; line-height:30px; height:30px;padding-left: 6px; " >
#
# **<i class="fa fa-pencil"></i> Activity 1 | Some basic operations on pandas dataframes**
#
# </div>

# %% [markdown]
# 1.1) Write a Pandas program to create a dataframe from a dictionary and display it.
# ```
# Sample data: {'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]}
# ```

# %%
dict_test = {'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]}

# %%
pandas.DataFrame(dict_test)
# Out:
#     X   Y   Z
# 0  78  84  86
# 1  85  94  97
# 2  96  89  96
# 3  80  83  72
# 4  86  86  83

# %% [markdown]
# 1.2) Write a Pandas program to create and display a DataFrame from a specified dictionary data which has the index labels.
# Sample Python dictionary data and list labels:
#
# ```
# exam_data = {
#
# 'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
# 'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
# 'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
# 'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']
#
# }
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```

# %%
exam_data = {
'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']

}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
exam_df = pandas.DataFrame(exam_data, index=labels)
exam_df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# 1.3.1. Using the previous dataframe get the first three rows

# %%
exam_df.iloc[:3]
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes

# %% [markdown]
# 1.3.2. Using the previous dataframe get the last three rows

# %%
exam_df.iloc[-3:]
# Out:
#     name  score  attempts qualify
# h  Laura    NaN         1      no
# i  Kevin    8.0         2      no
# j  Jonas   19.0         1     yes

# %% [markdown]
# 1.3.3. Select the 'name' and 'score' columns from the previous DataFrame.

# %%
exam_df.loc[:,['name', 'score']]
# Out:
#         name  score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5
# d      James    NaN
# e      Emily    9.0
# f    Michael   20.0
# g    Matthew   14.5
# h      Laura    NaN
# i      Kevin    8.0
# j      Jonas   19.0

# %% [markdown]
# 1.3.4. Select 'name' and 'score' columns in rows 1, 3, 5, 6 from the previous data frame:

# %%
exam_df.iloc[[1,3,5,6], 0:2]
# Out:
#       name  score
# b     Dima    9.0
# d    James    NaN
# f  Michael   20.0
# g  Matthew   14.5

# %% [markdown]
# 1.3.5 Select the rows where the number of attempts in the examination is greater than 2.

# %%
exam_df[exam_df.attempts>2]
# Out:
#       name  score  attempts qualify
# b     Dima    9.0         3      no
# d    James    NaN         3      no
# f  Michael   20.0         3     yes

# %% [markdown]
# 1.3.6 Select the rows where the score is missing, i.e. is NaN
#
# **Hint**: You can use `.isnull()`

# %%
exam_df[exam_df['score'].isnull()]
# Out:
#     name  score  attempts qualify
# d  James    NaN         3      no
# h  Laura    NaN         1      no

# %% [markdown]
# 1.3.7 Select the rows the score is between 15 and 20 (inclusive).

# %%
exam_df[ (exam_df.score>=15) & (exam_df.score<=20)]
# Out:
#         name  score  attempts qualify
# c  Katherine   16.5         2     yes
# f    Michael   20.0         3     yes
# j      Jonas   19.0         1     yes

# %% [markdown]
# 1.3.8 Select the rows where number of attempts in the examination is less than 2 and score greater than 15.

# %%
exam_df[ (exam_df.score>=15) & (exam_df.attempts<=2)]
# Out:
#         name  score  attempts qualify
# c  Katherine   16.5         2     yes
# j      Jonas   19.0         1     yes

# %% [markdown]
# 1.3.9 Change the score in row 'd' to 11.5.

# %%
exam_df.loc['d','score'] = 11.5

# %% [markdown]
# <div style="background-color: #86CBBB; font-size: 16px; line-height:30px; height:30px;padding-left: 6px; " >
#
# **<i class="fa fa-pencil"></i> Activity 2 | Pandas dataframe and input files:**
#
# </div>

# %% [markdown]
# ## Read csv and use pandas dataframe

# %% [markdown]
# Example of pandas dataframe operation using a synthetic dataset from Kaggle. See additional reference [here](https://www.kaggle.com/code/franciscomcm/five-useful-operations-with-pandas-dataframes/notebook)
#
# This dataset contains very basic examples to explore handy operations with Pandas DataFrames. There are 3 CSV files in the dataset:
# - `thermometer_A.csv` and `thermometer_B.csv` contain synthetic data representing temperature measurements over a full day by two devices.
# - `fertiliser_plant_growth.csv` contains synthetic data represeting the growth of 3 groups of plants (control, fertilizer A and fertilizer B).
#
# Find files in github or shared folder in Google Drive classroom under the `Data/Pandas_example.Fertilizer` folder

# %% [markdown]
# 1.1) Read information into a csv and show, describe, dimensions, etc

# %%
## read info to csv
fp_growth = pd.read_csv("../../shared_folder/Data/Pandas_example.Fertilizer/fertiliser_plant_growth.csv")

# %%
fp_growth.head()
# Out:
#        rate         Group  Baseline  Follow_up
# 0  1.395568       Control         0          1
# 1  1.128243       Control         1          2
# 2  0.369350       Control         2          3
# 3  0.278458       Control         3          4
# 4  3.759361  Fertiliser 1         0          1

# %%
fp_growth.ndim
# Out:
# 2

# %%
fp_growth.size
# Out:
# 48

# %%
fp_growth.shape
# Out:
# (12, 4)

# %%
fp_growth.describe()
# Out:
#             rate   Baseline  Follow_up
# count  12.000000  12.000000  12.000000
# mean    2.104354   1.500000   2.500000
# std     1.531007   1.167748   1.167748
# min     0.278458   0.000000   1.000000
# 25%     1.092795   0.750000   1.750000
# 50%     1.629273   1.500000   2.500000
# 75%     2.947877   2.250000   3.250000
# max     5.226792   3.000000   4.000000

# %%
## read info to csv
thermoA = pd.read_csv("../../shared_folder/Data/Pandas_example.Fertilizer/thermometer_A.csv")
thermoA.head()
# Out:
#    time  temperature_Celsius
# 0   0.0            20.806402
# 1   1.0            19.704943
# 2   2.0            20.009811
# 3   3.0            18.456799
# 4   4.0            19.079583

# %%
## read info to csv
thermoB = pd.read_csv("../../shared_folder/Data/Pandas_example.Fertilizer/thermometer_B.csv")
thermoB.head()
# Out:
#    time  temp_in_Cels
# 0   0.0     19.748056
# 1   1.0     22.437106
# 2   2.0     19.891827
# 3   3.0     20.968421
# 4   4.0     19.822151

# %% [markdown]
# 1.2) Add temperature from thermometer A and B to fertilizer dataframe

# %%
fp_growth['TempA'] = thermoA.temperature_Celsius

# %%
fp_growth['TempB'] = thermoB.temp_in_Cels

# %%
fp_growth
# Out:
#         rate         Group  Baseline  Follow_up      TempA      TempB
# 0   1.395568       Control         0          1  20.806402  19.748056
# 1   1.128243       Control         1          2  19.704943  22.437106
# 2   0.369350       Control         2          3  20.009811  19.891827
# 3   0.278458       Control         3          4  18.456799  20.968421
# 4   3.759361  Fertiliser 1         0          1  19.079583  19.822151
# 5   2.210381  Fertiliser 1         1          2  22.293422  19.266913
# 6   1.681038  Fertiliser 1         2          3  21.758095  20.310560
# 7   0.986452  Fertiliser 1         3          4  21.359306  20.501093
# 8   5.226792  Fertiliser 2         0          1  19.830271  18.148436
# 9   3.961708  Fertiliser 2         1          2  20.653192  18.602522
# 10  2.677383  Fertiliser 2         2          3  19.442273  22.096023
# 11  1.577509  Fertiliser 2         3          4  20.508328  20.186152

# %%
## time points: index IDs

# %%
fp_growth['time'] = fp_growth.index

# %% [markdown]
# 1.3) Find difference between temperature measures

# %%
fp_growth['Diff_tmp'] = fp_growth['TempA'] - fp_growth['TempB']

# %%
fp_growth
# Out:
#         rate         Group  Baseline  Follow_up      TempA      TempB  time  \
# 0   1.395568       Control         0          1  20.806402  19.748056     0
# 1   1.128243       Control         1          2  19.704943  22.437106     1
# 2   0.369350       Control         2          3  20.009811  19.891827     2
# 3   0.278458       Control         3          4  18.456799  20.968421     3
# 4   3.759361  Fertiliser 1         0          1  19.079583  19.822151     4
# 5   2.210381  Fertiliser 1         1          2  22.293422  19.266913     5
# 6   1.681038  Fertiliser 1         2          3  21.758095  20.310560     6
# 7   0.986452  Fertiliser 1         3          4  21.359306  20.501093     7
# 8   5.226792  Fertiliser 2         0          1  19.830271  18.148436     8
# 9   3.961708  Fertiliser 2         1          2  20.653192  18.602522     9
# 10  2.677383  Fertiliser 2         2          3  19.442273  22.096023    10
# 11  1.577509  Fertiliser 2         3          4  20.508328  20.186152    11
#
#     Diff_tmp
# 0   1.058346
# 1  -2.732163
# 2   0.117984
# 3  -2.511622
# 4  -0.742569
# 5   3.026509
# 6   1.447535
# 7   0.858214
# 8   1.681835
# 9   2.050671
# 10 -2.653750
# 11  0.322176

# %% [markdown]
# **<i class="fa fa-rocket"></i> Challenge**:

# %%
## Find the biggest absolute difference

# %%
abs(fp_growth.Diff_tmp)
# Out:
# 0     1.058346
# 1     2.732163
# 2     0.117984
# 3     2.511622
# 4     0.742569
# 5     3.026509
# 6     1.447535
# 7     0.858214
# 8     1.681835
# 9     2.050671
# 10    2.653750
# 11    0.322176
# Name: Diff_tmp, dtype: float64

# %%
max(abs(fp_growth.Diff_tmp))
# Out:
# 3.0265094079610897

# %%
fp_growth[ fp_growth['Diff_tmp'] == max(abs(fp_growth.Diff_tmp))]
# Out:
#        rate         Group  Baseline  Follow_up      TempA      TempB  time  \
# 5  2.210381  Fertiliser 1         1          2  22.293422  19.266913     5
#
#    Diff_tmp
# 5  3.026509

# %% [markdown]
# 1.4) Find meand and std between temperature measures

# %%
fp_growth
# Out:
#         rate         Group  Baseline  Follow_up      TempA      TempB  time  \
# 0   1.395568       Control         0          1  20.806402  19.748056     0
# 1   1.128243       Control         1          2  19.704943  22.437106     1
# 2   0.369350       Control         2          3  20.009811  19.891827     2
# 3   0.278458       Control         3          4  18.456799  20.968421     3
# 4   3.759361  Fertiliser 1         0          1  19.079583  19.822151     4
# 5   2.210381  Fertiliser 1         1          2  22.293422  19.266913     5
# 6   1.681038  Fertiliser 1         2          3  21.758095  20.310560     6
# 7   0.986452  Fertiliser 1         3          4  21.359306  20.501093     7
# 8   5.226792  Fertiliser 2         0          1  19.830271  18.148436     8
# 9   3.961708  Fertiliser 2         1          2  20.653192  18.602522     9
# 10  2.677383  Fertiliser 2         2          3  19.442273  22.096023    10
# 11  1.577509  Fertiliser 2         3          4  20.508328  20.186152    11
#
#     Diff_tmp
# 0   1.058346
# 1  -2.732163
# 2   0.117984
# 3  -2.511622
# 4  -0.742569
# 5   3.026509
# 6   1.447535
# 7   0.858214
# 8   1.681835
# 9   2.050671
# 10 -2.653750
# 11  0.322176

# %%
np.average(fp_growth.loc[:,['TempA', 'TempB']], axis=1)
# Out:
# array([20.27722927, 21.07102435, 19.95081906, 19.71261039, 19.45086699,
#        20.78016743, 21.03432781, 20.9301995 , 18.98935316, 19.62785695,
#        20.76914806, 20.34724028])

# %%
fp_growth['TempAverage'] = np.average(fp_growth.loc[:,['TempA', 'TempB']], axis=1)

# %%
fp_growth['Temp_std'] = np.std(fp_growth.loc[:,['TempA', 'TempB']], axis=1)

# %%
fp_growth
# Out:
#         rate         Group  Baseline  Follow_up      TempA      TempB  time  \
# 0   1.395568       Control         0          1  20.806402  19.748056     0
# 1   1.128243       Control         1          2  19.704943  22.437106     1
# 2   0.369350       Control         2          3  20.009811  19.891827     2
# 3   0.278458       Control         3          4  18.456799  20.968421     3
# 4   3.759361  Fertiliser 1         0          1  19.079583  19.822151     4
# 5   2.210381  Fertiliser 1         1          2  22.293422  19.266913     5
# 6   1.681038  Fertiliser 1         2          3  21.758095  20.310560     6
# 7   0.986452  Fertiliser 1         3          4  21.359306  20.501093     7
# 8   5.226792  Fertiliser 2         0          1  19.830271  18.148436     8
# 9   3.961708  Fertiliser 2         1          2  20.653192  18.602522     9
# 10  2.677383  Fertiliser 2         2          3  19.442273  22.096023    10
# 11  1.577509  Fertiliser 2         3          4  20.508328  20.186152    11
#
#     Diff_tmp  TempAverage  Temp_std
# 0   1.058346    20.277229  0.529173
# 1  -2.732163    21.071024  1.366081
# 2   0.117984    19.950819  0.058992
# 3  -2.511622    19.712610  1.255811
# 4  -0.742569    19.450867  0.371284
# 5   3.026509    20.780167  1.513255
# 6   1.447535    21.034328  0.723768
# 7   0.858214    20.930199  0.429107
# 8   1.681835    18.989353  0.840918
# 9   2.050671    19.627857  1.025335
# 10 -2.653750    20.769148  1.326875
# 11  0.322176    20.347240  0.161088

# %% [markdown]
# 1.5) Create some basic plots

# %% [markdown]
# 1.5.1 Use boxplot to plot rate of growth according to each group

# %%
fp_growth.boxplot('rate', by="Group")
# Out:
# <AxesSubplot:title={'center':'rate'}, xlabel='Group'>

# %% [markdown]
# 1.5.2. Plot temperature for thermometer A (or B) along time.

# %%
thermoA.plot(kind = 'scatter', x = 'time', y = 'temperature_Celsius')
#fp_growth.plot(kind = 'scatter', x='time', y = 'TempA')
# Out:
# <AxesSubplot:xlabel='time', ylabel='temperature_Celsius'>

# %%
thermoB.plot(kind = 'scatter', x = 'time', y = 'temp_in_Cels')
#fp_growth.plot(kind = 'scatter', x = 'time', y = 'TempB')
# Out:
# <AxesSubplot:xlabel='time', ylabel='temp_in_Cels'>

# %% [markdown]
# **<i class="fa fa-rocket"></i> Challenge**:
# 1.5.3. Create a plot along time for both temperature series.

# %%
import matplotlib.pyplot as plt 

# plot one by one 
plt.plot(fp_growth['TempA']) 
plt.plot(fp_growth['TempB']) 
  
# set y label 
plt.ylabel('Temperature') 
  
# set x label 
plt.xlabel('Time') 
  
# set title 
plt.title('Time') 

## set legend
plt.legend(["TempA", "TempB"])

# %% [markdown]
# 1.6) Create some filtering on your dataframe

# %%
fp_growth
# Out:
#         rate         Group  Baseline  Follow_up      TempA      TempB  time  \
# 0   1.395568       Control         0          1  20.806402  19.748056     0
# 1   1.128243       Control         1          2  19.704943  22.437106     1
# 2   0.369350       Control         2          3  20.009811  19.891827     2
# 3   0.278458       Control         3          4  18.456799  20.968421     3
# 4   3.759361  Fertiliser 1         0          1  19.079583  19.822151     4
# 5   2.210381  Fertiliser 1         1          2  22.293422  19.266913     5
# 6   1.681038  Fertiliser 1         2          3  21.758095  20.310560     6
# 7   0.986452  Fertiliser 1         3          4  21.359306  20.501093     7
# 8   5.226792  Fertiliser 2         0          1  19.830271  18.148436     8
# 9   3.961708  Fertiliser 2         1          2  20.653192  18.602522     9
# 10  2.677383  Fertiliser 2         2          3  19.442273  22.096023    10
# 11  1.577509  Fertiliser 2         3          4  20.508328  20.186152    11
#
#     Diff_tmp  TempAverage  Temp_std
# 0   1.058346    20.277229  0.529173
# 1  -2.732163    21.071024  1.366081
# 2   0.117984    19.950819  0.058992
# 3  -2.511622    19.712610  1.255811
# 4  -0.742569    19.450867  0.371284
# 5   3.026509    20.780167  1.513255
# 6   1.447535    21.034328  0.723768
# 7   0.858214    20.930199  0.429107
# 8   1.681835    18.989353  0.840918
# 9   2.050671    19.627857  1.025335
# 10 -2.653750    20.769148  1.326875
# 11  0.322176    20.347240  0.161088

# %% [markdown]
# 1.6.1. Only Control samples

# %%
fp_growth.Group == "Control"
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# Name: Group, dtype: bool

# %%
fp_growth[fp_growth.Group=='Control']
# Out:
#        rate    Group  Baseline  Follow_up      TempA      TempB  time  \
# 0  1.395568  Control         0          1  20.806402  19.748056     0
# 1  1.128243  Control         1          2  19.704943  22.437106     1
# 2  0.369350  Control         2          3  20.009811  19.891827     2
# 3  0.278458  Control         3          4  18.456799  20.968421     3
#
#    Diff_tmp  TempAverage  Temp_std
# 0  1.058346    20.277229  0.529173
# 1 -2.732163    21.071024  1.366081
# 2  0.117984    19.950819  0.058992
# 3 -2.511622    19.712610  1.255811

# %% [markdown]
# 1.6.2. Only Fertilsers samples: 1 & 2

# %%
fp_growth[fp_growth.Group!='Control']
# Out:
#         rate         Group  Baseline  Follow_up      TempA      TempB  time  \
# 4   3.759361  Fertiliser 1         0          1  19.079583  19.822151     4
# 5   2.210381  Fertiliser 1         1          2  22.293422  19.266913     5
# 6   1.681038  Fertiliser 1         2          3  21.758095  20.310560     6
# 7   0.986452  Fertiliser 1         3          4  21.359306  20.501093     7
# 8   5.226792  Fertiliser 2         0          1  19.830271  18.148436     8
# 9   3.961708  Fertiliser 2         1          2  20.653192  18.602522     9
# 10  2.677383  Fertiliser 2         2          3  19.442273  22.096023    10
# 11  1.577509  Fertiliser 2         3          4  20.508328  20.186152    11
#
#     Diff_tmp  TempAverage  Temp_std
# 4  -0.742569    19.450867  0.371284
# 5   3.026509    20.780167  1.513255
# 6   1.447535    21.034328  0.723768
# 7   0.858214    20.930199  0.429107
# 8   1.681835    18.989353  0.840918
# 9   2.050671    19.627857  1.025335
# 10 -2.653750    20.769148  1.326875
# 11  0.322176    20.347240  0.161088

# %% [markdown]
# 1.6.3 All fertilsers samples with baseline 1

# %%
fp_growth[(fp_growth.Group!='Control') & (fp_growth.Baseline==1)]
# Out:
#        rate         Group  Baseline  Follow_up      TempA      TempB  time  \
# 5  2.210381  Fertiliser 1         1          2  22.293422  19.266913     5
# 9  3.961708  Fertiliser 2         1          2  20.653192  18.602522     9
#
#    Diff_tmp  TempAverage  Temp_std
# 5  3.026509    20.780167  1.513255
# 9  2.050671    19.627857  1.025335

# %% [markdown]
# 1.6.4 All samples with TempA and TempB < 20

# %%
fp_growth[ (fp_growth.TempA<20) & (fp_growth.TempB <20)]
# Out:
#        rate         Group  Baseline  Follow_up      TempA      TempB  time  \
# 4  3.759361  Fertiliser 1         0          1  19.079583  19.822151     4
# 8  5.226792  Fertiliser 2         0          1  19.830271  18.148436     8
#
#    Diff_tmp  TempAverage  Temp_std
# 4 -0.742569    19.450867  0.371284
# 8  1.681835    18.989353  0.840918

# %% [markdown]
# 1.6.5 All samples with TempA or TempB < 20

# %%
fp_growth[ (fp_growth.TempA<20) | (fp_growth.TempB <20)]
# Out:
#         rate         Group  Baseline  Follow_up      TempA      TempB  time  \
# 0   1.395568       Control         0          1  20.806402  19.748056     0
# 1   1.128243       Control         1          2  19.704943  22.437106     1
# 2   0.369350       Control         2          3  20.009811  19.891827     2
# 3   0.278458       Control         3          4  18.456799  20.968421     3
# 4   3.759361  Fertiliser 1         0          1  19.079583  19.822151     4
# 5   2.210381  Fertiliser 1         1          2  22.293422  19.266913     5
# 8   5.226792  Fertiliser 2         0          1  19.830271  18.148436     8
# 9   3.961708  Fertiliser 2         1          2  20.653192  18.602522     9
# 10  2.677383  Fertiliser 2         2          3  19.442273  22.096023    10
#
#     Diff_tmp  TempAverage  Temp_std
# 0   1.058346    20.277229  0.529173
# 1  -2.732163    21.071024  1.366081
# 2   0.117984    19.950819  0.058992
# 3  -2.511622    19.712610  1.255811
# 4  -0.742569    19.450867  0.371284
# 5   3.026509    20.780167  1.513255
# 8   1.681835    18.989353  0.840918
# 9   2.050671    19.627857  1.025335
# 10 -2.653750    20.769148  1.326875
