# %% [markdown]
# # <i class="fa fa-laptop"></i> Bioinformatic Programming using Python
#
# <div style="background-color: #86CBBB; 1px; height:3px " ></div>
#
# Here, we will demonstrate some of the basics of programming Python. If you want to lean more, there are many more resources and other training sessions out there, including the official [Python Tutorial](https://docs.python.org/3/tutorial/).
#
# In this Jupyter _notebook_ you can answer and practice the exercises from this practical session.
#
# There are several icons that denome:
#
# * **<i class="fa fa-search"></i> Example**: Some code examples available for the topic of interest.
# * **<i class="fa fa-pencil"></i> Activitities**: These are actitivies to practice the lessons topics.
# * **<i class="fa fa-key"></i> Hint:** A small hint on how to solve the exercise.
# * **<i class="fa fa-cogs"></i> Code:** You write here the code. More than one line can be provided in the same code block. The symbol "..." expects to be replaced by some code.
# * **<i class="fa fa-file-code-o"></i> Script:** Intrusctions are provided to create an external script code using the terminal or other resources.
# * **<i class="fa fa-comment"></i> Comments:** Write your comments or notes in here if desired. This cell is formatted using Markdown. To activate it, click and write and then press Run or Execute.
# * **<i class="fa fa-rocket"></i> Challenge**: Activitities to test your coding skills.
#
# ## Getting Started
#
# Jupyter notebooks have two types of cells.  "Markdown" cells, like this one which can contain formatted text, and "Code" cells, which contain the code you will run.
#
# After you execute the cell, the result will automatically display underneath the cell.
#
#
# ## Jupyter menu
#
# To use the jupyter menu there are several buttons and options. See below a small description, see additional details [here](https://jupyter.brynmawr.edu/services/public/dblank/Jupyter%20Notebook%20Users%20Manual.ipynb) or [here](https://jupyter-notebook.readthedocs.io/en/latest/examples/Notebook/Notebook%20Basics.html#Notebook-Basics)
#
# * <i class="fa fa-save"></i> This is your save button. You can click this button to save your notebook at any time, though keep in mind that Jupyter Notebooks automatically save your progress very frequently.
#
# * <i class="fa fa-plus"></i> This is the new cell button. You can click this button any time you want a new cell in your Jupyter Notebook.
#
# * <i class="fa fa-scissors"></i> This is the cut cell button. If you click this button, the cell you currently have selected will be deleted from your Notebook.
#
# * <i class="fa fa-copy"></i> This is the copy cell button. If you click this button, the currently selected cell will be duplicated and stored in your clipboard.
#
# * <i class="fa fa-paste"></i> This is the past button. It allows you to paste the duplicated cell from your clipboard into your notebook.
#
# * <i class="fa fa-arrow-up"></i><i class="fa fa-arrow-down"></i> These buttons allow you to move the location of a selected cell within a Notebook. Simply select the cell you wish to move and click either the up or down button until the cell is in the location you want it to be.
#
# * <i class="fa fa-step-forward"></i> This button will "run" your cell, meaning that it will interpret your input and render the output in a way that depends on what type of cell you're using.
#
# * <i class="fa fa-step-forward"></i> This is the restart kernel button. See your kernel documentation for more information.
#
# * <i class="fa fa-stop"></i> This is the stop button. Clicking this button will stop your cell from continuing to run. This tool can be useful if you are trying to execute more complicated code, which can sometimes take a while, and you want to edit the cell before waiting for it to finish rendering.
#
# * <i class="fa fa-repeat"></i> esborra les variables que hi havia guardades fins al moment
#
#
# There are also several shorcuts available, check the list in:
#
# ![image-2.png](attachment:image-2.png)
#
# Some examples:
#
# **Edit mode**: Enter
# **Run cell**: Shift-Enter, Ctrl-Enter,
# **Basic browsing**: , up arrow/k, down arrow/j, esc <br>
# **Save the notebook**: S
# **Change cell format type**: M, Y
# **Create new cells**: A ( insert cell above), B (insert cell below)
# **Edit cells**: X (Cut), C (Copy), V (Paste) D (Delete), Z (Undo cell selection)
# **Show keyboard shorcuts**: H
#
# <br>
#
#  <div style="background-color: #86CBBB; 1px; height:3px " ></div>

# %% [markdown]
# ## Some Basics
# Let's review a few basic features of programming.

# %% [markdown]
# **A note about print()**
#
# * By default, a Colab/Jupyter notebook will print out the output from the last line, so you don't have to specify the `print()` command.
# * However, it is recommended if we want to output the results from additional lines, we need to use `print()` on each line.

# %% [markdown]
# ## 1. Some basic introduction to python
# Let's review a few basic features of python programming.

# %% [markdown]
# ### 1.1. Direct Mode (Use Jupyter Notebook)
# <br>
# <br>
# <div style="background-color: #86CBBB; font-size: 16px; line-height:30px; height:30px;padding-left: 6px; " >
#
# **<i class="fa fa-pencil"></i> Activity 1 | Mandatory example: _Hello world!_**
#
# </div>
#
# The very first execution everybody has to create for the first time when learning a new programming language. Use built-in function `print()` to say hello. Remember to use quoates, either single or double (even triple).
#
# **<i class="fa fa-cogs"></i></p> Code:**

# %% [markdown]
# ### 1.2 Python as a calculator

# %% [markdown]
# First, it's great for math.  You can use addition (+), subtraction (-), multiplication (\*), division (/) and exponents (**). Produce some examples
#
# ### <i class="fa fa-search"></i> Exemple

# %%
# Addition
1542+1244

# %%
# Product
24*45

# %% [markdown]
# **<i class="fa fa-cogs"></i> Code:** Create some examples

# %%
# Your Turn: Try some math here

# %%
# Another one: get the power or exponent of a number

# %%
#

# %% [markdown]
# Remenber that the order of operations is also important.

# %%
print(5 * 2 + 3)

# %%
print(5 * (2+3))

# %%
print((5 * 2) + 3)

# %% [markdown]
# **<i class="fa fa-comment"></i> Comments:** Write your comments or notes in the following cell if desired. That cell is formatted using Markdown. To activate it, click and write and then press Run or Execute.

# %% [markdown]
# <div style="background-color: #86CBBB; font-size: 16px; line-height:30px; height:30px;padding-left: 6px; " >
#
# **<i class="fa fa-pencil"></i> Activity 2 | Arithmetics with python:**
#
# </div>
#
# Create a command that produces the following results operation: $\left(\frac{3+2}{2\cdot 5}\right)^2$ = 0.25.

# %% [markdown]
# ## 2. Variables in Python
# Let's review a few basic features of python variables using the following examples:
# ### <i class="fa fa-search"></i> Exemple

# %%
# An integer
num = 4

# A floating number
numFloat = 1.2 

# Define a string (single or double quotes)
string1 = 'ATAGCTAGGCGATGC' 
string2 = "ATAGCTAGGCGATGC" 

# Create multiple assignments in a single line
a, b = 3, 4

# Create double assignments
c = d = 5 

# Assign values 
e = 1
# Re-assign values
e = 2

# %% [markdown]
# Check some values of the previous variables

# %%
## Are string1 and string2 the same? Use ==

# %%
# the value of b

# %%
# Check the value of e: it contains the last assignment

# %% [markdown]
# Check the type of the following variables. Use a built-in function available.

# %% [markdown]
# **<i class="fa fa-key"></i> Hint:** A small hint on how to solve the exercise.
#
# So far, we can use type() or class() indisctincly. Further details: https://realpython.com/python-metaclasses/#type-and-class

# %% [markdown]
# **<i class="fa fa-cogs"></i> Code:** Create some examples

# %%
## check the type of num

# %%
## check the type of numFloat

# %%
## check the type of string1

# %% [markdown]
# Force a number to be a string and concatenate strings

# %%
# A string needs to be in quotes (single or double)
z = 'Python is great'

# If you convert an integer into a string, you can then catenate them
print( z + ' ' + str(num) + ' you!' )

# %% [markdown]
# <br>
# <div style="background-color: #86CBBB; font-size: 16px; line-height:30px; height:30px;padding-left: 6px; " >
#
# **<i class="fa fa-pencil"></i> Activity 3 | Variable assignments**
#
# </div>

# %% [markdown]
# Let's work on variable assignment.
#
# - Create three different variables with your Name and Age
# - Check the type of each of these variables
# - Create a sentence where you use them all in a single print() call
#
# As an example:
#
# _My name is Jose, I am 36 years old_

# %% [markdown]
# <br>
# <div style="background-color: #86CBBB; font-size: 16px; line-height:30px; height:30px;padding-left: 6px; " >
#
# **<i class="fa fa-pencil"></i> Activity 4 | Nested assignments**
#
# </div>

# %% [markdown]
# Imagine you execute the following commands

# %% [markdown]
# ```
# >>> x = 1
# >>> y = 2
# >>> x = y
# ```
#
# What is the value of x? And y?

# %% [markdown]
# How do you interchange the values of both variables using multiple assignments (in a single line)?

# %% [markdown]
# ### 2.1. Numbers in Python
# ### <i class="fa fa-search"></i> Exemple

# %%
a = -542
b = 12.24
b = c

# %% [markdown]
# **<i class="fa fa-cogs"></i> Code:** Create some examples

# %%
# Get the absolute value of number a

# %%
# Evaluate using operator == if number b is equal to c

# %% [markdown]
# Now, create some number conversions

# %%
# convert variable num a to a floating number

# %%
# get the round integer of numFloat variable

# %% [markdown]
# <br>
# <div style="background-color: #86CBBB; font-size: 16px; line-height:30px; height:30px;padding-left: 6px; " >
#
# **<i class="fa fa-pencil"></i> Activity 5 | Explain the performance of modulo operator "%"**
#
# </div>

# %%
5 % 2

# %%
4 % 2

# %%
6 % 2

# %%
## Try another one

# %% [markdown]
# **<i class="fa fa-comment"></i> Comments:** Write your comments or notes in the following cell if desired. That cell is formatted using Markdown. To activate it, click and write and then press Run or Execute.

# %% [markdown]
# **<i class="fa fa-key"></i> Hint:** A small hint on how to solve the exercise.
#
# Check this explanation [here](https://www.freecodecamp.org/news/the-python-modulo-operator-what-does-the-symbol-mean-in-python-solved/)

# %%
## Can you imagine a situation to use it? Show an example or write an explanation where to use it

# %% [markdown]
# <div style="background-color: #86CBBB; font-size: 16px; line-height:30px; height:30px;padding-left: 6px; " >
#
# **<i class="fa fa-pencil"></i> Activity 6 | Calculate the BMI index with python:**
#
# </div>
#
# Create a command that given the weight and the height, it calculates the BMI index.

# %% [markdown]
# **<i class="fa fa-key"></i> Hint:** A small hint on how to solve the exercise.
#
# Remenber that bmi = weight / (height ** 2)

# %% [markdown]
# ### 2.2. String variables in Python
# ### <i class="fa fa-search"></i> Exemple

# %%
sentence="A long and useless sentence to test Python strings methods"

# %%
# all uppercase
sentence.upper()

# %%
# all lowercase
sentence.lower()

# %%
# replace useless with other adjective
sentence.replace("useless", "useful")

# %% [markdown]
# Now, some string slicing examples:

# %%
sentence[0]

# %%
sentence[2:6]

# %%
sentence[9:6:-1]

# %%
# find a starting point to the end
sentence[sentence.find('Python'):]

# %% [markdown]
# <br>
# <div style="background-color: #86CBBB; font-size: 16px; line-height:30px; height:30px;padding-left: 6px; " >
#
# **<i class="fa fa-pencil"></i> Activity 7 | String methods min() and max()**
#
# </div>
#
# What do results of the methods max() and min() mean when applied to a character string?

# %%
max(sentence)

# %%
min(sentence)

# %% [markdown]
# **<i class="fa fa-comment"></i> Comments:** Write your comments or notes in the following cell if desired. That cell is formatted using Markdown. To activate it, click and write and then press Run or Execute.

# %% [markdown]
# ### <i class="fa fa-search"></i> Exemple
#
# Check other methods when working with strings in python

# %%
dna_example = "ATTTGACTGATCGACTCCCCCC"

# %%
# Count how many Gs
dna_example.count("G")

# %%
# Count the lenght
len(dna_example)

# %%
# Duplicate sequence
dna_example*2

# %%
# Calculate the number of purine bases
dna_example.count("A") + dna_example.count("G")

# %%
# Transcribe to RNA
dna_example.replace("T", "U")

# %%
# Check if string starts with a given letter
dna_example.startswith("A")

# %%
# Check if string ends with a given letter
dna_example.endswith("A")

# %%
## Find the presence of a substring
"CCCCCC" in dna_example

# %% [markdown]
# <br>
# <div style="background-color: #86CBBB; font-size: 16px; line-height:30px; height:30px;padding-left: 6px; " >
#
# **<i class="fa fa-pencil"></i> Activity 8 | DNA strings**
#
# </div>

# %% [markdown]
# Given the following sequence

# %%
dnaHCGB = "..."

# %% [markdown]
# **<i class="fa fa-pencil"></i> Activity 8.1 | Check the length of the DNA sequence provided**
#
# Find the length of the DNA string provided
#
# **<i class="fa fa-cogs"></i></p> Code:**

# %% [markdown]
# **<i class="fa fa-pencil"></i> Activity 8.2 | String formatting: GC% Content**
#
# Calculate the GC content of the previous DNA sequence and print it in a sentence using 2 floating points and the % character.
#
# Example output:
#
# _DNA sequence provided contains 42.10% of GC gontent_
#
# **<i class="fa fa-cogs"></i></p> Code:**

# %% [markdown]
# **<i class="fa fa-pencil"></i> Activity 8.3 | Restriction Enzyme site**
#
# We want to know if the given sequence contains any given restriction site. Can you check the following enzyme restriction sites?
#
# ```
# EcoRI: G*AATTC
# SmaI:  CCC*GGG
# BamHI: G*GATCC
# ```
#
# **<i class="fa fa-key"></i> Hint:** A small hint on how to solve the exercise.
#
# Symbol "*" only denotes the restriction starting site.
#
# **<i class="fa fa-cogs"></i></p> Code:**

# %% [markdown]
# **<i class="fa fa-pencil"></i> Activity 8.4 | Obtaining exon sequences**
#
# The HCGB unit has found evidences for exons within the sequence. There is a coding sequence from position 3-405, another from 504-899 and finally, a third coding sequence from position 970 to the end. Can you subset them and save them as independent objects.
#
# **<i class="fa fa-key"></i> Hint:** A small hint on how to solve the exercise.
#
# Take into account the starting point at 0 when Python slicing strings
#
# **<i class="fa fa-cogs"></i></p> Code:**

# %% [markdown]
# **<i class="fa fa-pencil"></i> Activity 8.5 | Concatenating into CDS**
#
# Create a new variable named CDS from the exon sequences 1, 2 and 3.+
#
# **<i class="fa fa-cogs"></i></p> Code:**

# %% [markdown]
# **<i class="fa fa-pencil"></i> Activity 8.6 | Find a given motif in the CDS sequence**
#
# Search the motif "GCACACACG" and provide the position
#
# **<i class="fa fa-cogs"></i></p> Code:**

# %% [markdown]
# **<i class="fa fa-pencil"></i> Activity 8.7 | Create an _in silico_ resitriction cut**
#
# Use the previous enzymes that could cut the CDS and identify the length of the fragments generated.
#
#
# **<i class="fa fa-cogs"></i></p> Code:**

# %% [markdown]
# **<i class="fa fa-pencil"></i> Activity 8.8 | Find the melting temperature**
#
# Calculate the melting temperature of the CDS.
#
# **<i class="fa fa-key"></i> Hint:** A small hint on how to solve the exercise.
#
# Melting temperature can be calculated following the formula:
#
# $$T = 2 * (numA + numT) + 4 * (numG +numC)$$
#
# **<i class="fa fa-cogs"></i></p> Code:**

# %% [markdown]
# **<i class="fa fa-pencil"></i> Activity 8.9 | Transcribe the CDS to mRNA**
#
# Transcribe the CDS sequence to mRNA.
#
#
# **<i class="fa fa-key"></i> Hint:** A small hint on how to solve the exercise.
#
# Remember to change Ts by Us and reverse the string.
#
# **<i class="fa fa-cogs"></i></p> Code:**

# %% [markdown]
# **<i class="fa fa-pencil"></i> Activity 8.10 | Add a poylG cap and polyA tail**
#
# Add at the 5' end a GTP head represented by Gppp- and at the end, a tail of 50 As
#
# **<i class="fa fa-cogs"></i></p> Code:**

# %% [markdown]
# <br>
# <br>
# <div style="background-color: #86CBBB; font-size: 16px; line-height:30px; height:30px;padding-left: 6px; " >
#
# **<i class="fa fa-pencil"></i> Activity 9 | Mandatory example: _Hello world!_ using a text script**
#
# </div>
#
# #### <i class="fa fa fa-file-code-o" aria-hidden="true"></i> Script Mode (Use text file and Terminal in Jupyter Dashboard)
#
# The very first execution everybody has to create for the first time when learning a new programming language.
# Use built-in function `print()` to say hello. Remember to use quoates, either single or double (even triple).
#
# **<i class="fa fa-key"></i> Hint:** A small hint on how to solve the exercise.
#
# Use the script mode:
# - Open a New text file in the Jupyter Dashboard
#
# ![image-6.png](attachment:image-6.png)
#
# - Renamed as: _test.py_ or any other name with _.py_
#
#
# ![image-7.png](attachment:image-7.png)
#
# - Write your code
#
# - Open a terminal and find your script
#
# ![image-5.png](attachment:image-5.png)
#
#
# The following table simplifies the commands in the Windows PowerShell Terminal and in the Mac/Linux terminal
#
# | Command          | Function                           |
# |--------------|-------------------------------------------------------|
# | `pwd`          | Show the working directory |
# | `ls`           | Show the items, files and folders in the current working directory         |
# | `cd <dir>`     | Change directory |
# | `cat <file>`   | Show the content of a file |
# | `mkdir <name>` | Create a new folder |
#
# See details on how to work in a Windows Terminal in [here](https://github.com/asalber/aprendeconalf/blob/master/content/es/docencia/python/herramientas/terminal-windows/index.md)
#  and in a MacOS terminal [here](https://github.com/asalber/aprendeconalf/blob/master/content/es/docencia/python/herramientas/terminal-macos/index.md)
#
#
# - Execute it by typing: _python script.py_

# %% [markdown]
# <br>
# <br>
# <div style="background-color: #86CBBB; font-size: 16px; line-height:30px; height:30px;padding-left: 6px; " >
#
# **<i class="fa fa-pencil"></i> Activity 10 | Find the bug**
#
# </div>

# %% [markdown]
# Some code blocks are provided with an error. Identify the type of error and fix it

# %%
1+x

# %%
ind="Pepe"
print("Hello " + id)

# %%
numbers=[1,4,5,6,7]
print(numbers)
print(numbers[5])

# %%
numerator=0
denominator=0
results = numerator/denominator

# %%
# calculate BMI:  bmi = weight / (height ** 2)
weight = 65
height = 1.65

bmi=weight/height*2
print(bmi)
